# %% [markdown]
# <a href="https://colab.research.google.com/github/BrishavDebnath/Mid-Semester-Assignment/blob/main/Space_Mini_Encyclopaedia_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A Astronomy Mini Encyclopaedia
# Creating a dictionary which will store all the objects or items for my encyclopaedia.
space_objects = {
    "SUN": {
        "Type": "Star",
        "Description": """The largest object in our solar system.\nThe Sun is a giant ball of hot plasma, primarily consisting of hydrogen and helium, that generates energy through nuclear fusion.\nIts gravity holds the solar system together. The Sun's surface temperature is around 5,500 degrees Celsius, with a much hotter core reaching millions of degrees.\nSolar flares and prominences erupt from the Sun's surface, affecting Earth's atmosphere and technology.""",

    },
    "EARTH": {
        "Type": "Planet",
        "Description": """The third planet from the Sun, and the only known planet to support life as we know it.\nEarth has a layered structure with a solid iron core, a mantle of rock, and a thin crust.\nIts atmosphere, composed mainly of nitrogen and oxygen, protects life from harmful solar radiation.\nEarth's unique combination of temperature, liquid water, and a magnetic field creates a habitable environment for diverse life forms.""",

    },
    "MOON": {
        "Type": "Natural Satellite",
        "Description": """Earth's only natural satellite, a rocky body with a cratered surface.\nThe Moon plays a crucial role in stabilizing Earth's axis and influencing tides.\nIt is believed to have formed from the debris of a giant impact early in Earth's history.\nThe Moon has no atmosphere and experiences extreme temperature variations.\nHumans have landed on the Moon only once, during the Apollo missions in the late 1960s and early 1970s.""",

    },
    "MARS": {
        "Type": "Planet",
        "Description": """The fourth planet from the Sun, known for its reddish color due to the presence of iron oxide (rust) on its surface.\nMars has a thin atmosphere composed mainly of carbon dioxide.\nEvidence suggests the presence of ancient water on Mars, with frozen water ice caps at its poles.\nThe planet has two moons, Phobos and Deimos, which are likely captured asteroids.\nMars is a prime target in the search for extraterrestrial life.""",

    },
    "JUPITER": {
        "Type": "Gas Giant",
        "Description": """The largest planet in our solar system, a massive ball of gas with a thick atmosphere composed primarily of hydrogen and helium.\nJupiter has a strong magnetic field and a complex system of rings.\nThe planet is known for its Great Red Spot, a giant anticyclonic storm that has been raging for centuries.\nJupiter has numerous moons, with the four largest (Io, Europa, Ganymede, and Callisto) known as the Galilean moons.""",

    },

    "VENUS": {
        "Type": "Planet",
        "Description": """The second planet from the Sun, with a thick atmosphere of carbon dioxide that traps heat, making it the hottest planet in the solar system.\nVenus has a similar size and mass to Earth, but its surface conditions are vastly different.\nThe planet has a volcanic surface with evidence of past volcanic activity.\nIts thick atmosphere creates a crushing pressure on the surface.""",

    },
    "MERCURY": {
        "Type": "Planet",
        "Description": """The smallest planet in our solar system, closest to the Sun.\nMercury has no atmosphere and experiences extreme temperature variations, ranging from scorching hot days to freezing cold nights.\nThe planet's surface is heavily cratered due to impacts from asteroids and comets. Mercury has a weak magnetic field and a very thin exosphere.""",

    },
    "SATURN": {
        "Type": "Gas Giant",
        "Description": """The sixth planet from the Sun, known for its prominent rings made of ice and dust particles.\nSaturn is a gas giant with a thick atmosphere composed mainly of hydrogen and helium.\nThe planet has a weak magnetic field and numerous moons, including Titan, the largest moon in the solar system with a thick atmosphere and liquid methane lakes.""",

      },
    "URANUS": {
        "Type": "Ice Giant",
        "Description": """The seventh planet from the Sun, an ice giant with a unique tilted axis and a ring system composed of dark, dusty particles.\nUranus has a thick atmosphere composed primarily of hydrogen and helium, with methane ice clouds giving it a blueish hue.\nThe planet has numerous moons, with the five largest known as the Uranian moons.""",

    },
    "NEPTUNE": {
        "Type": "Ice Giant",
        "Description": """The eighth and farthest planet from the Sun, another ice giant with strong winds and a blue appearance.\nNeptune has a thick atmosphere composed mainly of hydrogen and helium, with methane ice clouds.\nThe planet has a Great Dark Spot, a giant anticyclonic storm similar to Jupiter's Great Red Spot.\nNeptune has numerous moons, with Triton, the largest, having a retrograde orbit and a geyser field of frozen nitrogen.""",

    },
    "ASTEROID": {
        "Type": "Rocky Body",
        "Description": """Relatively small, rocky objects orbiting the Sun, mostly found in the asteroid belt between Mars and Jupiter.\nAsteroids vary in size and composition, with some containing valuable metals.\nThey are remnants of the early solar system's formation and can pose a threat to Earth if they collide on a collision course.""",

    },
    "COMET": {
        "Type": "Icy Body",
        "Description": """Icy objects with tails of gas and dust that become visible when near the Sun.\nComets consist of a frozen core of ice, dust, and rock, with a surrounding coma and tail that develop as they approach the Sun.\nComets originate from the Kuiper Belt beyond Neptune and the Oort Cloud in the far outer solar system.""",

    },
    "BLACK HOLE": {
        "Type": "Stellar Collapse",
        "Description": """A region of spacetime with such immense gravity that nothing, not even light, can escape.\nBlack holes are formed by the collapse of massive stars and have a point of singularity with infinite density.\nThe presence of a black hole can be inferred by its gravitational influence on surrounding matter.\nSupermassive black holes are believed to reside at the centers of most galaxies.""",

    },
    "NEBULA": {
        "Type": "Interstellar Cloud",
        "Description": """Giant clouds of gas and dust where stars are born and die.\nNebulae come in various shapes and sizes, with emission nebulae glowing from the energy of nearby hot stars, reflection nebulae reflecting the light of nearby stars, and planetary nebulae formed from the ejected material of dying stars.""",

    },
    "GALAXY": {
        "Type": "Massive Collection of Stars",
        "Description": """Vast collections of billions of stars, gas, dust, and dark matter.\nGalaxies come in various shapes, including spiral, elliptical, and irregular galaxies.\nOur Milky Way galaxy is a spiral galaxy with a central bulge, spiral arms, and a surrounding disk.\nGalaxies interact with each other through gravitational forces and may eventually merge.""",

    },
    "QUASAR": {
        "Type": "Active Galactic Core",
        "Description": """Extremely luminous and distant active galactic nuclei, powered by supermassive black holes at the centers of galaxies.\nQuasars emit vast amounts of energy across the electromagnetic spectrum.\nThey are believed to be fueled by the in-falling of matter into the black hole.""",

    },
    "DWARF PLANET": {
        "Type": "Celestial Body",
        "Description": """A celestial body that is round under its own gravity but is not massive enough to clear its orbital neighborhood of other objects.\nDwarf planets are smaller than planets but larger than asteroids and comets.\nExamples include Pluto, Eris, Ceres, Haumea, and Makemake.""",

    },
    "ASTEROID BELT": {
        "Type": "Region",
        "Description": """A region between Mars and Jupiter containing a large number of asteroids, mostly rocky objects left over from the formation of the solar system.\nThe size and composition of asteroids vary greatly.\nSome asteroids have been mined for resources, and some pose a potential threat to Earth if their orbit intersects with ours.""",

    },
    "KUIPER BELT": {
        "Type": "Region",
        "Description": """A region beyond Neptune containing a vast number of icy objects, including dwarf planets, Kuiper Belt Objects (KBOs), and comets.\nThe Kuiper Belt is believed to be a remnant of the solar system's formation and may hold clues to the early history of our solar system.""",

    },
    "OORT CLOUD": {
        "Type": "Theoretical Region",
        "Description": """A giant, spherical cloud of icy objects at the very edge of the solar system, too distant to be directly observed.\nThe Oort Cloud is believed to be the source of long-period comets that enter the inner solar system.\nThe existence of the Oort Cloud is inferred based on the observed orbits of comets.""",

    },
    "PULSAR": {
        "Type": "Rotating Neutron Star",
        "Description": """A rapidly rotating neutron star that emits beams of radiation that sweep across space like a lighthouse.\nPulsars are formed from the collapse of a massive star in a supernova and can rotate hundreds of times per second.\nThey can be used as incredibly precise clocks in astronomy.""",

    },
    "EXOPLANET": {
        "Type": "Planet Outside Solar System",
        "Description": """A planet orbiting a star outside our solar system.\nExoplanets have been discovered in recent decades using various methods, including the transit method and the radial velocity method.\nThe study of exoplanets helps us understand the diversity of planetary systems and the possibility of life beyond Earth.""",

    },
    "HABITABLE ZONE": {
        "Type": "Theoretical Region",
        "Description": """The region around a star where the conditions are suitable for liquid water to exist on the surface of a planet.\nThis is considered a key criterion for the possibility of life as we know it.\nThe habitable zone depends on the star's luminosity and the planet's atmospheric composition.""",

    },
    "SUPERNOVA": {
        "Type": "Stellar Explosion",
        "Description": """A powerful explosion of a massive star at the end of its life cycle.\nSupernovae release enormous amounts of energy, light, and elements heavier than hydrogen and helium, enriching the interstellar medium.\nThey can also trigger the formation of new stars and planetary systems.\nDifferent types of supernovae exist depending on the star's mass and composition.""",

    },
    "STELLAR NEBULA": {
        "Type": "Nebula Type",
        "Description": """A type of nebula formed from the ejected material of a dying star, particularly red giants or asymptotic giant branch stars.\nStellar nebulae can be categorized as planetary nebulae, bipolar nebulae, or reflection nebulae based on their shape and interaction with starlight.""",

    },
    "COSMIC MICROWAVE BACKGROUND RADIATION": {
        "Type": "Radiation",
        "Description": """The faint afterglow of the Big Bang, filling the entire observable universe.\nThis cosmic microwave background radiation is a remnant of the hot, dense early universe and provides vital clues about its origin and evolution.\nThe CMB is almost uniform in all directions, with tiny temperature fluctuations that hold information about the early structure of the universe.""",

    },
    "DARK MATTER": {
        "Type": "Hypothetical Substance",
        "Description": """A mysterious form of matter that is believed to make up a significant portion of the universe's mass but cannot be directly observed.\nDark matter interacts with gravity but not with light, making it difficult to detect.\nEvidence for dark matter comes from its gravitational effects on visible matter, such as the rotation of galaxies and the movement of matter in galaxy clusters.""",

    },
    "DARK ENERGY": {
        "Type": "Hypothetical Form of Energy",
        "Description": """Another mysterious form of energy that is believed to be driving the accelerated expansion of the universe.\nDark energy is even less understood than dark matter, but it is thought to permeate all of space and have a repulsive gravitational effect.\nUnderstanding dark energy is crucial for comprehending the ultimate fate of the universe.""",

    },
    "MAGELLAN CLOUD": {
        "Type": "Irregular Galaxy",
        "Description": """Dwarf irregular galaxies that are satellite companions to our Milky Way galaxy.\nThe Large Magellanic Cloud (LMC) and the Small Magellanic Cloud (SMC) are the two most prominent members.\nThese galaxies contain young stars, star clusters, gas, and dust, offering valuable insights into star formation and galactic evolution.""",

    },
    "ACTIVE GALACTIC NUCLEUS": {
        "Type": "Galaxy Core",
        "Description": """The extremely bright and energetic central region of a galaxy, powered by a supermassive black hole.\nAGNs can emit vast amounts of radiation across the electromagnetic spectrum, including radio waves, infrared radiation, visible light, X-rays, and gamma rays.\nDifferent types of AGNs exist depending on the orientation of the accretion disk surrounding the black hole and the line of sight from Earth.""",

    },
    "ASTROBIOLOGY": {
        "Type": "Field of Study",
        "Description": """The interdisciplinary field of science that studies the origin, evolution, and distribution of life in the universe.\nAstrobiology draws upon various disciplines like astronomy, biology, chemistry, geology, and physics to explore the possibility of life beyond Earth.\nIt investigates planetary environments, searches for exoplanets suitable for life, and explores the potential for life on other celestial bodies in our solar system.""",

    },
    "RED GIANT": {
        "Type": "Stellar Evolution Stage",
        "Description": """A red giant is a star in a later stage of its evolution, following the main sequence phase for stars like our Sun.\nAs a star's core hydrogen fuel depletes, it begins to fuse helium in its core, causing the star to expand significantly.\nThis expansion cools the star's surface, giving it its characteristic reddish hue. Red giants are much larger than main sequence stars, with some reaching hundreds of times the Sun's diameter.\nDespite their cooler surface temperatures, red giants are actually more luminous than main sequence stars due to their vast size.\nThe evolution of a star into a red giant can have a dramatic impact on its planetary system.\nThe expanding star can engulf nearby planets, and the intense radiation can strip away the atmospheres of planets further out.\nUnderstanding red giants is crucial for comprehending the life cycle of stars and their impact on planetary systems."""
    },
    "WHITE DWARF": {
        "Type": "Stellar Remnant",
        "Description": """A white dwarf is the leftover core of a star that has exhausted its nuclear fusion fuel.\nAfter a red giant phase, low- and medium-mass stars shed their outer layers, forming a planetary nebula.\nThe remaining core collapses under its own gravity, becoming a white dwarf.\nWhite dwarfs are incredibly dense, with a teaspoon of material weighing tons on Earth.\nDespite their high density, white dwarfs are relatively faint because they no longer generate energy through fusion.\nThey slowly cool over time, eventually becoming black dwarfs, though the timescale for this cooling process is vast.\nStudying white dwarfs provides insights into the later stages of stellar evolution and the fate of our Sun."""
    },
    "NEUTRON STAR": {
        "Type": "Stellar Remnant",
        "Description": """An incredibly dense and compact remnant of a massive star that has undergone a supernova explosion.  Neutron stars are formed when the core of a massive star collapses in on itself during the supernova. The immense pressure crushes the protons and electrons in the core, forcing them to combine into neutrons.  Neutron stars are the densest objects in the observable universe, exceeding the density of atomic nuclei.  They spin very rapidly, sometimes hundreds of times per second, due to the conservation of angular momentum during the collapse.  Neutron stars can emit powerful beams of radiation if they have a strong magnetic field, creating phenomena like pulsars and magnetars."""
    },
    "BINARY STAR SYSTEM": {
        "Type": "Stellar Grouping",
        "Description": """A binary star system consists of two stars gravitationally bound to each other, orbiting a common center of mass.\nBinary star systems are quite common, with estimates suggesting that over half of all stars in the Milky Way are part of such a system.\nBinary stars can influence each other's evolution through gravitational interactions and mass transfer.\nStudying binary star systems can reveal details about stellar evolution,  the formation of massive stars and supernovae, and the potential for planets to form in such systems."""
    },
    "GLOBULAR CLUSTER": {
        "Type": "Star Cluster",
        "Description": """A globular cluster is a tightly packed collection of hundreds of thousands to millions of old stars, all bound together by gravity.\nGlobular clusters are ancient structures, formed billions of years ago during the early stages of our galaxy's formation.\nThey are mostly spherical in shape and contain a high concentration of low-mass stars, unlike the diverse stellar populations found in open clusters.\nStudying globular clusters provides valuable information about the formation and evolution of galaxies,  as they offer a snapshot of the early universe."""
    },
    "OPEN CLUSTER": {
        "Type": "Star Cluster",
        "Description": """An open cluster is a loose collection of stars, typically containing a few hundred to a few thousand stars, bound together by gravity.\nOpen clusters are generally younger than globular clusters, formed from the collapse of giant molecular clouds in the spiral arms of galaxies.\nThe stars in open clusters are more diverse in mass and age compared to globular clusters.\nOver time, the gravitational pull of the surrounding galaxy disrupts open clusters, dispersing the stars over millions of years.\nStudying open clusters helps us understand star formation processes and the early stages of stellar evolution."""
    },
    "PLANETARY NEBULA": {
        "Type": "Nebula Type",
        "Description": """A beautiful and short-lived astronomical phenomenon that occurs when a dying low- or medium-mass star sheds its outer layers during its red giant phase.\nThe intense heat from the star's exposed core causes the ejected gas and dust to glow, creating a colorful nebula with intricate shapes.\nPlanetary nebulae play a crucial role in enriching the interstellar medium with elements heavier than hydrogen and helium, which are essential for the formation of new stars and planetary systems.\nThe lifespan of a planetary nebula is relatively short, lasting only a few thousand years, before it fades and disperses into the interstellar medium."""
    },
    "WOLF RAYET STAR": {
        "Type": "Massive Star",
        "Description": """A rare and short-lived type of massive star nearing the end of its life cycle.\nWolf-Rayet stars are characterized by their extremely hot surface temperatures, strong stellar winds, and the presence of elements heavier than hydrogen and helium in their atmospheres.\nThese elements are ejected through powerful winds, enriching the surrounding interstellar medium.\nWolf-Rayet stars are massive and luminous, often exceeding 20 times the mass of the Sun.\nHowever, their intense stellar winds cause them to lose mass rapidly, leading to a relatively short lifespan.\nStudying Wolf-Rayet stars helps us understand the evolution of massive stars and their role in the formation of supernovae and stellar black holes."""
    },
    "GRAVITATIONAL WAVES": {
        "Type": "Disturbance in Spacetime",
        "Description": """Ripples in the fabric of spacetime caused by accelerating massive objects.\nPredicted by Einstein's theory of general relativity, gravitational waves were directly detected in 2015, marking a major breakthrough in our understanding of gravity and the universe.\nThese waves carry information about the events that caused them, such as the collision of black holes or neutron stars.\nGravitational wave astronomy opens a new window for observing the universe, allowing us to study phenomena that cannot be observed with traditional telescopes."""
    },
    "HUBBLE CONSTANT": {
        "Type": "Cosmological Parameter",
        "Description": """A crucial constant in cosmology that represents the current rate of expansion of the universe.\nThe Hubble constant is expressed in units of kilometers per second per megaparsec."""
    },
    "PROPLANETARY DISK": {
        "Type": "Circumstellar Disk",
        "Description": """A swirling disk of gas and dust orbiting a young star during its early stages of formation.\nThis dusty disk is the birthplace of planetary systems.\nThe gravity of the young star pulls material inward, eventually leading to the formation of planets, moons, and asteroids.\nThe composition of a protoplanetary disk can vary, containing elements like hydrogen, helium, heavier elements from the star's formation, and even icy particles.\nStudying protoplanetary disks helps us understand the processes of planet formation and the conditions that give rise to different planetary systems."""
    },
    "EXOPLANET ATMOSPHERE": {
        "Type": "Planetary Feature",
        "Description": """The gaseous layer surrounding an exoplanet, potentially offering clues about the planet's habitability and composition.\nStudying exoplanet atmospheres is a complex task, as these planets are often far away from Earth.\nHowever, advancements in telescopes and techniques like spectroscopy allow us to analyze the light that passes through an exoplanet's atmosphere, revealing the presence of certain gases like water vapor, methane, or carbon dioxide.\nThe composition of an exoplanet's atmosphere can tell us about its potential for liquid water, the presence of greenhouse gases, and the overall suitability for life as we know it."""
    },
    "COSMIC DUST": {
        "Type": "Interstellar Material",
        "Description": """Tiny particles of solid material found throughout the interstellar medium.\nCosmic dust is composed of various elements and molecules, including silicates, carbon, and ice.\nThese dust particles play a crucial role in the life cycle of stars and planetary systems.\nDust absorbs and scatters light, causing interstellar reddening and affecting our view of distant objects.\nDust also provides surfaces for chemical reactions to occur, leading to the formation of more complex molecules needed for star and planet formation."""
    },
    "SUPERNOVA REMNANT": {
        "Type": "Stellar Debris",
        "Description": """The expanding cloud of gas and dust left behind after a massive star explodes in a supernova.\nThe explosion ejects the star's outer layers at tremendous speeds, creating a shockwave that sweeps through the surrounding interstellar medium.\nSupernova remnants play a significant role in enriching the interstellar medium with heavy elements forged in the star's core.\nThese elements are essential for the formation of new stars and planetary systems.\nThe structure and evolution of a supernova remnant can vary depending on the type of supernova and the surrounding environment."""
    },
    "PLUTO": {
        "Type": "Dwarf Planet",
        "Description": """Pluto, once classified as the ninth planet in our solar system, is now recognized as a dwarf planet located in the Kuiper Belt beyond Neptune.\nThis icy world holds a special place in our understanding of the solar system.\nDespite its reclassification, Pluto remains an important object for study.\nIt is the largest known dwarf planet by volume, even exceeding the dwarf planet Eris in that regard.\nPluto's composition is primarily rock and ice, with a thin atmosphere composed of nitrogen, methane, and carbon monoxide.\nIts surface displays a diverse range of features, including mountains, plains, craters, and even glaciers made of nitrogen ice.\nPluto has five known moons, the largest being Charon, which is unusually large relative to Pluto itself, almost reaching half its diameter.\nThe Pluto-Charon system is considered a double dwarf planet due to their close proximity and possible tidal locking.\nStudying Pluto and its moons provides valuable insights into the formation and evolution of the outer solar system and the icy objects that reside beyond the orbit of Neptune."""
    },
    "SOLAR FLARE": {
        "Type": "Stellar Eruption",
        "Description": """A sudden and powerful eruption of hot plasma from the Sun's surface.\nSolar flares release tremendous amounts of energy, including light, X-rays, and energetic particles.\nThese eruptions can disrupt Earth's magnetosphere, causing auroras (northern and southern lights) and potentially impacting satellites and power grids.\nThe intensity of solar flares varies, with some being relatively minor while others can be extremely powerful.\nStudying solar flares helps us understand the Sun's activity and its impact on Earth and the surrounding space environment."""
    },
    "PROMINENCE": {
        "Type": "Solar Feature",
        "Description": """A large loop or cloud of hot plasma that erupts from the Sun's surface and extends outward into the solar corona.\nProminences can be quite spectacular, stretching for hundreds of thousands of kilometers.\nUnlike solar flares, prominences typically do not release a large amount of energy but can remain suspended for days or even weeks.\nThe magnetic field lines trap the hot plasma in prominences, giving them their characteristic loop-like shape.\nStudying prominences provides insights into the Sun's magnetic field and its interaction with the solar corona."""
    },
    "EXOPLANET MOON": {
        "Type": "Potential Object",
        "Description": """A hypothetical moon orbiting an exoplanet.\nWhile no exoplanet moons have been definitively confirmed yet, astronomers are actively searching for them using various techniques.\nThe discovery of exoplanet moons would be a significant breakthrough in our understanding of planetary systems beyond our own.\nExoplanet moons could potentially harbor conditions suitable for life, especially if they reside within the habitable zone of their host star.\nStudying the possibility of exoplanet moons requires advanced observation techniques and the analysis of potential signatures that might indicate their presence."""
    },
    "ASTROPHYSICS": {
        "Type": "Scientific Field",
        "Description": """Astrophysics is a branch of astronomy that applies the principles of physics to understand celestial objects and phenomena.\nIt encompasses a vast range of topics, from the formation and evolution of stars and galaxies to the study of dark matter, black holes, and the early universe.\nAstrophysicists utilize various tools and techniques, including telescopes, satellites, and computer systems to the night sky and its wonderful mysteries!"""
    },
    "MULTIVERSE": {
        "Type": "Hypothetical Concept",
        "Description": """The multiverse is a hypothetical concept that proposes the existence of multiple universes beyond our own observable universe.\nThis theoretical framework suggests that our universe is just one among a vast collection of universes, potentially with different physical laws and realities.\nThe idea of the multiverse arises from various cosmological and philosophical considerations.\nSome interpretations of quantum mechanics and string theory also suggest the possibility of multiple universes.\nWhile there is currently no scientific evidence to directly confirm the existence of a multiverse, it remains a fascinating concept that continues to spark debate and inspire scientific exploration."""
    },
    "UNIVERSE": {
        "Type": "Cosmos",
        "Description": """The universe encompasses everything - all of space and time, all forms of matter and energy, and the physical laws and constants that govern them.\nIt's the totality of existence, including galaxies, stars, planets, black holes, light, and even the tiniest subatomic particles.\nThe vastness of the universe is mind-boggling, with an estimated observable universe diameter of around 93 billion light-years.\nOur understanding of the universe is constantly evolving.\nThe prevailing cosmological theory, the Big Bang, suggests that the universe began from an incredibly hot, dense state roughly 13.8 billion years ago and has been expanding and cooling ever since.\nHowever, there are many mysteries that remain unsolved, such as the nature of dark matter and dark energy, which are believed to make up most of the universe's energy content.\nStudying the universe helps us understand our place in the cosmos, the origin and evolution of everything that exists, and the fundamental laws that govern reality.\nThe universe is a vast and wondrous place, filled with beauty, mystery, and endless possibilities for exploration."""
    },
    "BIG BANG": {
        "Type": "Cosmological Model",
        "Description": """The Big Bang theory is the prevailing cosmological model for the universe's origin and evolution.\nIt states that the universe began from an incredibly hot, dense state approximately 13.8 billion years ago and has been expanding and cooling ever since.\nEvidence for the Big Bang comes from various observations, including the cosmic microwave background radiation, the abundance of light elements in the universe, and the redshift of distant galaxies.\n

                          The Big Bang theory proposes several stages in the universe's evolution:\n

                       * **Inflation:**  An extremely rapid expansion of the universe in its earliest moments, explaining the universe's large-scale uniformity.\n
                       * **Radiation Era:**  The universe was dominated by radiation and extremely hot.\n
                       * **Matter Era:**  As the universe cooled, matter particles like protons and neutrons formed, leading to the creation of the first atoms.\n
                       * **Epoch of Recombination:**  Electrons and protons combined to form neutral atoms, allowing light to travel freely. The cosmic microwave background radiation is a remnant of this era.\n
                       * **Structure Formation:**  Gravity pulled matter together, forming the first stars and galaxies.\n

                         The Big Bang theory is constantly being refined as new observations and data become available.\nIt remains the most widely accepted explanation for the origin and evolution of the universe, providing a comprehensive framework for understanding our cosmic history."""
    },
    "ASTROLOGY": {
        "Type": "Belief System",
        "Description": """Astrology is a belief system that claims that the positions of celestial objects like stars and planets at the time of a person's birth or a specific event hold influence over human behavior and life experiences.\nIt assigns zodiac signs based on a person's birthdate and interprets planetary alignments to make predictions about personality, relationships, and future events.\n

                        Astrology has a long history dating back to ancient civilizations.\nWhile some people find meaning and guidance in astrological interpretations, it lacks scientific basis.\nThe positions of celestial objects at birth haven't been shown to have a causal effect on human personality or life events.  Scientific studies have found no correlation between astrological predictions and reality.\n

                        Despite the lack of scientific evidence, astrology remains a popular cultural practice for some.\nIt's important to distinguish astrology from astronomy, which is the scientific study of celestial objects and phenomena."""
    },
    "STEADY STATE THEORY": {
        "Type": "Cosmological Model (Alternative to Big Bang)",
        "Description": """The steady-state theory is an alternative cosmological model to the Big Bang theory.\nProposed in the mid-20th century, it suggests that the universe has always existed and will continue to exist forever in a state of constant expansion.\nThis theory argues that the universe maintains a uniform density as it expands because new matter is continuously being created throughout space to fill the void left by the expansion.\n

                          The steady-state theory faced challenges in explaining the existence of the cosmic microwave background radiation, a remnant of the Big Bang, and the observed redshift of distant galaxies, which indicates their movement away from us.\nThese observations provided stronger evidence for the Big Bang theory, leading to the decline in the acceptance of the steady-state theory within the scientific community.\n

                          However, the steady-state theory offered a simpler model of the universe compared to the Big Bang theory at the time.\nWhile no longer widely accepted, it played a crucial role in stimulating scientific debate and further research on the origin and evolution of the universe."""
    },
    "BIG CRUNCH THEORY": {
        "Type": "Cosmological Model (Alternative to Big Bang)",
        "Description": """The Big Crunch theory is a hypothetical cosmological model that proposes the eventual collapse of the universe.\nThis theory suggests that the expansion of the universe will eventually slow down and reverse due to the gravitational pull of all the matter within it.\nAs the universe collapses, galaxies and eventually all structures will be drawn closer together, culminating in a singularity similar to the Big Bang but in reverse.\n

                       The Big Crunch theory faces challenges from recent observations suggesting that the expansion of the universe is accelerating, driven by dark energy.\nThis contradicts the notion of a slowing down and eventual reversal of the expansion.\nAdditionally, the theory doesn't offer a clear explanation for what might happen at the singularity or how the universe might bounce back from it, if at all.\n

                       While the Big Crunch theory is not currently favored by most cosmologists, it remains a fascinating hypothetical scenario for the ultimate fate of the universe.\nFuture observations and advancements in our understanding of dark energy and gravity will be crucial in determining the validity of this theory."""
    },
}


# This function searches for a object in the dictionary using it's key and prints it value as output.
def display_object(object_name):

  if object_name in space_objects:
    object_data = space_objects[object_name]
    print(f"\n** {object_name.upper()} **")
    print(f"Type: {object_data['Type']}")
    print(f"Description: {object_data['Description']}")

  else:
    print(f"Sorry, information about '{object_name}' is not available.")

# This function lists all the keys available in the dictionary and prints it.
def list_objects():
  print("\n** Space Objects in Encyclopedia **")
  for object_name in space_objects:
    print(object_name)

# This is where the main control of the program lies. This includes listing all the keys present, getting their values and exiting the program.
while True:
  print("\n** Mini Space Encyclopedia **")
  print("1. List Space Objects")
  print("2. Get Information About an Object")
  print("3. Exit")

  choice = input("Enter your choice (1-3): ")

  if choice == '1':
    list_objects()
  elif choice == '2':
    object_name = input("Enter the name of the space object: ").capitalize()
    display_object(object_name.upper())
  elif choice == '3':
    print("Exiting Encyclopedia...")
    break
  else:
    print("Invalid choice. Please try again.")

print("Thank you for using the Mini Space Encyclopedia!")
# Out:
# ** Mini Space Encyclopedia **
# 1. List Space Objects
# 2. Get Information About an Object
# 3. Exit
# Enter your choice (1-3): 1
#
# ** Space Objects in Encyclopedia **
# SUN
# EARTH
# MOON
# MARS
# JUPITER
# VENUS
# MERCURY
# SATURN
# URANUS
# NEPTUNE
# ASTEROID
# COMET
# BLACK HOLE
# NEBULA
# GALAXY
# QUASAR
# DWARF PLANET
# ASTEROID BELT
# KUIPER BELT
# OORT CLOUD
# PULSAR
# EXOPLANET
# HABITABLE ZONE
# SUPERNOVA
# STELLAR NEBULA
# COSMIC MICROWAVE BACKGROUND RADIATION
# DARK MATTER
# DARK ENERGY
# MAGELLAN CLOUD
# ACTIVE GALACTIC NUCLEUS
# ASTROBIOLOGY
# RED GIANT
# WHITE DWARF
# NEUTRON STAR
# BINARY STAR SYSTEM
# GLOBULAR CLUSTER
# OPEN CLUSTER
# PLANETARY NEBULA
# WOLF RAYET STAR
# GRAVITATIONAL WAVES
# HUBBLE CONSTANT
# PROPLANETARY DISK
# EXOPLANET ATMOSPHERE
# COSMIC DUST
# SUPERNOVA REMNANT
# PLUTO
# SOLAR FLARE
# PROMINENCE
# EXOPLANET MOON
# ASTROPHYSICS
# MULTIVERSE
# UNIVERSE
# BIG BANG
# ASTROLOGY
# STEADY STATE THEORY
# BIG CRUNCH THEORY
#
# ...
